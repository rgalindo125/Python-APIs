# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Python script to visualize the weather of 500+ cities across the world of varying distance from the equator using CityPy, a simple Python library, and the OpenWeatherMap API.
#
# The visualizations includce a series of scatter plots to showcase the following relationships:
#
# Temperature (F) vs. Latitude Humidity (%) vs. Latitude Cloudiness (%) vs. Latitude Wind Speed (mph) vs. Latitude
#
# The script accomplishes the following:
#
# Randomly selects at least 500 unique (non-repeat) cities based on latitude and longitude.
#
# Performs a weather check on each of the cities using a series of successive API calls.
#
# Includes a print log of each city as it's being processed with the city number and city name.
#
# Saves both a CSV of all data retrieved and png images for each scatter plot.
#
# Observable Trends
# Not surprisingly, temperature increases as we approach the equator. However, temperature peaks at around 20 degrees latitude, not exactly at the equatorial line. This may be due to the Earth's tilt in the axis known as obliquity.
#
# Cloudiness and humidity do not show a strong correlation to latitude. The visualizations below show a great variety of values at similar latitudes.
#
# Wind speed appears to slightly increase as we move away from the equator.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities_list = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities_list:
        cities_list.append(city)

# Print the city count to confirm sufficient count
print(len(cities_list))
cities_list
# Out:
# 602
# ['albany',
#  'monywa',
#  'maningrida',
#  'kodiak',
#  'mar del plata',
#  'kapaa',
#  'ushuaia',
#  'quatre cocos',
#  'souillac',
#  'saint-pierre',
#  'barrow',
#  'areia branca',
#  'port elizabeth',
#  'luderitz',
#  'mangan',
#  'puerto ayora',
#  'victoria',
#  'gunnedah',
#  'ridgecrest',
#  'taolanaro',
#  'ishigaki',
#  'dalvik',
#  'cabedelo',
#  'butaritari',
#  'castro',
#  'olden',
#  'new norfolk',
#  'talnakh',
#  'lebu',
#  'vila velha',
#  'thompson',
#  'zheleznogorsk',
#  'hobart',
#  'rikitea',
#  'busselton',
#  'geraldton',
#  'ancud',
#  'port alfred',
#  'pisco',
#  'belushya guba',
#  'punta arenas',
#  'cairns',
#  'atuona',
#  'jamestown',
#  'iqaluit',
#  'bluff',
#  'avarua',
#  'kaitangata',
#  'khuzdar',
#  'khatanga',
#  'victor harbor',
#  'mount gambier',
#  'woodward',
#  'mataura',
#  'the pas',
#  'ornskoldsvik',
#  'hithadhoo',
#  'mikhaylovka',
#  'hambantota',
#  'kruisfontein',
#  'bredasdorp',
#  'altay',
#  'harer',
#  'mehamn',
#  'cape town',
#  'sitka',
#  'illoqqortoormiut',
#  'klaksvik',
#  'belaya gora',
#  'ngukurr',
#  'louisbourg',
#  'jaszbereny',
#  'saint george',
#  'laguna',
#  'galgani',
#  'hirara',
#  'coronon',
#  'shemonaikha',
#  'mahebourg',
#  'tessalit',
#  'severo-kurilsk',
#  'changji',
#  'vaini',
#  'provideniya',
#  'chokurdakh',
#  'longyearbyen',
#  'kununurra',
#  'nacala',
#  'fortuna',
#  'ixtapa',
#  'saldanha',
#  'bathsheba',
#  'kavieng',
#  'mufulira',
#  'hasaki',
#  'bereda',
#  'khonuu',
#  'port macquarie',
#  'byron bay',
#  'tiksi',
#  'japura',
#  'houma',
#  'barentsburg',
#  'piopio',
#  'aklavik',
#  'san patricio',
#  'cidreira',
#  'cosala',
#  'rio gallegos',
#  'cam ranh',
#  'chuy',
#  'pangnirtung',
#  'carnarvon',
#  'tsogni',
#  'east london',
#  'hilo',
#  'coswig',
#  'clyde river',
#  'lhokseumawe',
#  'dikson',
#  'tabas',
#  'santa maria',
#  'grafton',
#  'yakeshi',
#  'esperance',
#  'jalu',
#  'qaanaaq',
#  'samarai',
#  'canby',
#  'cayenne',
#  'nantucket',
#  'killybegs',
#  'ishinomaki',
#  'lorengau',
#  'hermanus',
#  'dalnerechensk',
#  'aflu',
#  'tagusao',
#  'ostrovnoy',
#  'lima',
#  'crixas',
#  'lisala',
#  'dunedin',
#  'upernavik',
#  'yellowknife',
#  'flinders',
#  'grindavik',
#  'fiche',
#  'neyshabur',
#  'pangoa',
#  'port lincoln',
#  'mao',
#  'washington',
#  'tojsici',
#  'tumannyy',
#  'vardo',
#  'half moon bay',
#  'ronne',
#  'richha',
#  'anadyr',
#  'kolchugino',
#  'port hardy',
#  'cagayan de tawi-tawi',
#  'vammala',
#  'comodoro rivadavia',
#  'san alberto',
#  'haldibari',
#  'guerrero negro',
#  'rawannawi',
#  'san cristobal',
#  'cabo san lucas',
#  'atambua',
#  'nhulunbuy',
#  'tevriz',
#  'tucuman',
#  'aloleng',
#  'saint-philippe',
#  'nikolskoye',
#  'saleaula',
#  'tasiilaq',
#  'katsuura',
#  'willowmore',
#  'along',
#  'beringovskiy',
#  'nizwa',
#  'taksimo',
#  'diffa',
#  'lata',
#  'alofi',
#  'gram',
#  'mont-dore',
#  'bambous virieux',
#  'salinas',
#  'mundo nuevo',
#  'kholodnyy',
#  'srivardhan',
#  'georgetown',
#  'touros',
#  'novyy urengoy',
#  'canutama',
#  'sao joao da barra',
#  'richards bay',
#  'bethel',
#  'urucara',
#  'vila franca do campo',
#  'pingliang',
#  'coquimbo',
#  'ola',
#  'leningradskiy',
#  'marghita',
#  'andreapol',
#  'rudbar',
#  'sao filipe',
#  'fairbanks',
#  'ponta do sol',
#  'mayo',
#  'kichera',
#  'hanstholm',
#  'aquiraz',
#  'tuktoyaktuk',
#  'falealupo',
#  'lokosovo',
#  'zhoucheng',
#  'palana',
#  'wuan',
#  'kijang',
#  'saskylakh',
#  'agirish',
#  'nemuro',
#  'arraial do cabo',
#  'lufilufi',
#  'amderma',
#  'port hedland',
#  'vera cruz',
#  'puli',
#  'kiunga',
#  'scottsbluff',
#  'abu kamal',
#  'hofn',
#  'viloco',
#  'bolungarvik',
#  'verkh-usugli',
#  'cherskiy',
#  'tsihombe',
#  'cairo',
#  'warmbad',
#  'turukhansk',
#  'sarangani',
#  'inhambane',
#  'kadoma',
#  'fomboni',
#  'ahipara',
#  'bodden town',
#  'khandyga',
#  'lompoc',
#  'tabanan',
#  'brae',
#  'fukue',
#  'palabuhanratu',
#  'tokzar',
#  'ashitkovo',
#  'pevek',
#  'calama',
#  'rocha',
#  'gat',
#  'diu',
#  'moranbah',
#  'vysokogornyy',
#  'kahului',
#  'faanui',
#  'gamba',
#  'puerto penasco',
#  'scarborough',
#  'hurricane',
#  'bubaque',
#  'sovetskoye',
#  'abu dhabi',
#  'port-gentil',
#  'lubyany',
#  'olinda',
#  'sinnamary',
#  'ribeira grande',
#  'codrington',
#  'sentyabrskiy',
#  'sokolo',
#  'urumqi',
#  'novyy urgal',
#  'jasper',
#  'dedza',
#  'san ramon',
#  'auki',
#  'port augusta',
#  'yumen',
#  'alice springs',
#  'solnechnyy',
#  'kolokani',
#  'saint-augustin',
#  'saint anthony',
#  'nishihara',
#  'airai',
#  'halifax',
#  'pandan',
#  'nerchinskiy zavod',
#  'banjar',
#  'amarillo',
#  'radovis',
#  'yerbogachen',
#  'bengkulu',
#  'zunyi',
#  'berlevag',
#  'hobyo',
#  'pringsewu',
#  'yar-sale',
#  'parana',
#  'alexandroupoli',
#  'san lorenzo',
#  'uk',
#  'longlac',
#  'sungairaya',
#  'namibe',
#  'meyungs',
#  'las vegas',
#  'gedo',
#  'nizhneyansk',
#  'traverse city',
#  'la orilla',
#  'torbay',
#  'masuda',
#  'tutoia',
#  'attawapiskat',
#  'dien bien',
#  'te anau',
#  'burnie',
#  'vytegra',
#  'haines junction',
#  'nome',
#  'martil',
#  'kuldur',
#  'fort wellington',
#  'groningen',
#  'karamea',
#  'bo rai',
#  'petropavlovsk-kamchatskiy',
#  'miles city',
#  'kirakira',
#  'acapulco',
#  'dawlatabad',
#  'salalah',
#  'tyulgan',
#  'daru',
#  'moroni',
#  'tornio',
#  'north bend',
#  'anloga',
#  'whitehorse',
#  'tahoua',
#  'camacha',
#  'bafra',
#  'papetoai',
#  'komsomolskiy',
#  'college',
#  'hammerfest',
#  'cassilandia',
#  'dzhusaly',
#  'dawson creek',
#  'saint-joseph',
#  'narsaq',
#  'belmonte',
#  'guatire',
#  'udachnyy',
#  'dinguiraye',
#  'kamenka',
#  'yangmei',
#  'satitoa',
#  'raymond',
#  'leeton',
#  'karla',
#  'vostok',
#  'hanzhong',
#  'lewistown',
#  'terney',
#  'yatou',
#  'rawson',
#  'devgarh',
#  'cuiluan',
#  'olafsvik',
#  'minsk',
#  'prince rupert',
#  'ilulissat',
#  'gambela',
#  'sabang',
#  'noshiro',
#  'roncesvalles',
#  'xinzhou',
#  'veinticinco de mayo',
#  'paita',
#  'harper',
#  'corrales',
#  'itarema',
#  'hamilton',
#  'kulhudhuffushi',
#  'jiddah',
#  'qaqortoq',
#  'severo-yeniseyskiy',
#  'puntarenas',
#  'tilichiki',
#  'lipin bor',
#  'santa cruz',
#  'vilhena',
#  'kon tum',
#  'sao raimundo nonato',
#  'anahuac',
#  'panama city',
#  'okhotsk',
#  'siva',
#  'bara',
#  'orocue',
#  'sabha',
#  'mount isa',
#  'skibbereen',
#  'makaha',
#  'tonantins',
#  'husavik',
#  'road town',
#  'awjilah',
#  'dauphin',
#  'mago',
#  'astara',
#  'abancay',
#  'dwarka',
#  'kaman',
#  'caravelas',
#  'vanavara',
#  'aswan',
#  'bourail',
#  'seymchan',
#  'sapao',
#  'ararangua',
#  'black river',
#  'garowe',
#  'almaguer',
#  'yinchuan',
#  'marrakesh',
#  'yulara',
#  'boende',
#  'pacific grove',
#  'lagoa',
#  'honiara',
#  'atbasar',
#  'luanda',
#  'roald',
#  'madang',
#  'gawler',
#  'teyateyaneng',
#  'calamar',
#  'kuche',
#  'manokwari',
#  'grand river south east',
#  'terenos',
#  'honningsvag',
#  'los llanos de aridane',
#  'kimbe',
#  'bolonchen',
#  'palmer',
#  'manolas',
#  'ormara',
#  'sangmelima',
#  'norsup',
#  'barkly west',
#  'roma',
#  'morehead',
#  'huarmey',
#  'bonfim',
#  'cervo',
#  'hegang',
#  'poronaysk',
#  'erenhot',
#  'norman wells',
#  'astana',
#  'adrar',
#  'asau',
#  'beyneu',
#  'balaguer',
#  'sao raimundo das mangabeiras',
#  'warwick',
#  'sapa',
#  'formoso do araguaia',
#  'basco',
#  'zhigansk',
#  'benito juarez',
#  'farafenni',
#  'komatipoort',
#  'mbekenyera',
#  'labuan',
#  'taltal',
#  'walvis bay',
#  'high level',
#  'carauari',
#  'jieshi',
#  'florenville',
#  'alekseyevsk',
#  'barra da estiva',
#  'catamarca',
#  'goundam',
#  'carndonagh',
#  'atar',
#  'labuhan',
#  'fevralsk',
#  'rutland',
#  'klyuchi',
#  'jiaohe',
#  'mys shmidta',
#  'lethem',
#  'karratha',
#  'malanje',
#  'houston',
#  'tautira',
#  'vao',
#  'christchurch',
#  'selfoss',
#  'marzuq',
#  'brunsbuttel',
#  'fort nelson',
#  'maragogi',
#  'lumberton',
#  'corrente',
#  'svetlyy',
#  'timmins',
#  'ruatoria',
#  'saint-denis',
#  'makakilo city',
#  'kamenz',
#  'nguiu',
#  'atherton',
#  'kieta',
#  'churapcha',
#  'conde',
#  'lobito',
#  'kaoma',
#  'carutapera',
#  'mukhen',
#  'moose factory',
#  'maniitsoq',
#  'lahat',
#  'nanortalik',
#  'mezhdurechensk',
#  'dicabisagan',
#  'benguela',
#  'rafaela',
#  'gold coast',
#  'kang',
#  'egvekinot',
#  'sao felix do xingu',
#  'watari',
#  'shwebo',
#  'okahandja',
#  'kabinda',
#  'vitimskiy',
#  'san javier',
#  'padang',
#  'dietzenbach',
#  'tuatapere',
#  'kushmurun',
#  'tinjah',
#  'saraland',
#  'sohag',
#  'zhuhai',
#  'lingao',
#  'waw',
#  'tupik',
#  'plouzane',
#  'taboga',
#  'dillon',
#  'saint-francois',
#  'nuuk',
#  'virginia beach',
#  'homer',
#  'trairi',
#  'chara',
#  'bur gabo',
#  'constitucion',
#  'ceara-mirim',
#  'maceio',
#  'kavaratti',
#  'marawi',
#  'jagraon',
#  'tecoanapa',
#  'ossora',
#  'sivas',
#  'poum',
#  'susanville',
#  'katherine',
#  'malangwa',
#  'agboville',
#  'sept-iles',
#  'irbeyskoye',
#  'concarneau',
#  'the valley',
#  'oriximina',
#  'huilong',
#  'iquique',
#  'mehran']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# an API call is made up of a couple of things
# 1.) base url -> location, everything after the base url -> 'order' configuration
# 2.) send the order
# 3.) do something with the returned object

# 1.) URL
# parts:            location        |      configuration...                  password                    specifics

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q=kawalu"

# send the order, receive back the finished goods
kawalu_data = requests.get(url).json()
kawalu_data
# Out:
# {'coord': {'lon': 108.21, 'lat': -7.38},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 65.14,
#   'pressure': 1013.34,
#   'humidity': 92,
#   'temp_min': 65.14,
#   'temp_max': 65.14,
#   'sea_level': 1013.34,
#   'grnd_level': 945.69},
#  'wind': {'speed': 2.71, 'deg': 60.945},
#  'clouds': {'all': 88},
#  'dt': 1563998419,
#  'sys': {'message': 0.0071,
#   'country': 'ID',
#   'sunrise': 1564009238,
#   'sunset': 1564051584},
#  'timezone': 25200,
#  'id': 1640902,
#  'name': 'Kawalu',
#  'cod': 200}

# %%
# process the order -> City	Cloudiness	Country	Date	Humidity	Lat	Lng	Max Temp	Wind Speed
compact_data = {
    'City': kawalu_data['name'],
    'Cloudiness': kawalu_data['clouds']['all'],
    'Country': kawalu_data['sys']['country'],
    'Date': kawalu_data['dt'],
    'Humidity': kawalu_data['main']['humidity'],
    'Lat': kawalu_data['coord']['lat'],
    'Lng': kawalu_data['coord']['lon'],
    'Max Temp': kawalu_data['main']['temp_max'],
    'Wind Speed': kawalu_data['wind']['speed']
}

compact_data
# Out:
# {'City': 'Kawalu',
#  'Cloudiness': 88,
#  'Country': 'ID',
#  'Date': 1563998419,
#  'Humidity': 92,
#  'Lat': -7.38,
#  'Lng': 108.21,
#  'Max Temp': 65.14,
#  'Wind Speed': 2.71}

# %%
# OpenWeatherMap API Key
# api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities_list:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=albany
# Processing Record 2 | Monywa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=monywa
# Processing Record 3 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=maningrida
# Processing Record 4 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kodiak
# Processing Record 5 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mar del plata
# Processing Record 6 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kapaa
# Processing Record 7 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ushuaia
# Processing Record 8 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=quatre cocos
# Processing Record 9 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=souillac
# Processing Record 10 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint-pierre
# Processing Record 11 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=barrow
# Processing Record 12 | Areia Branca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=areia branca
# Processing Record 13 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port elizabeth
# Processing Record 14 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=luderitz
# Processing Record 15 | Mangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mangan
# Processing Record 16 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=puerto ayora
# Processing Record 17 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=victoria
# Processing Record 18 | Gunnedah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=gunnedah
# Processing Record 19 | Ridgecrest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ridgecrest
# City not found. Skipping...
# Processing Record 20 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ishigaki
# Processing Record 21 | Dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dalvik
# Processing Record 22 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cabedelo
# Processing Record 23 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=butaritari
# Processing Record 24 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=castro
# Processing Record 25 | Olden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=olden
# Processing Record 26 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=new norfolk
# Processing Record 27 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=talnakh
# Processing Record 28 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lebu
# Processing Record 29 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vila velha
# Processing Record 30 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=thompson
# Processing Record 31 | Zheleznogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=zheleznogorsk
# Processing Record 32 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hobart
# Processing Record 33 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=rikitea
# Processing Record 34 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=busselton
# Processing Record 35 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=geraldton
# Processing Record 36 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ancud
# Processing Record 37 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port alfred
# Processing Record 38 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pisco
# City not found. Skipping...
# Processing Record 39 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=punta arenas
# Processing Record 40 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cairns
# Processing Record 41 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=atuona
# Processing Record 42 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jamestown
# Processing Record 43 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=iqaluit
# Processing Record 44 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bluff
# Processing Record 45 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=avarua
# Processing Record 46 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kaitangata
# Processing Record 47 | Khuzdar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=khuzdar
# Processing Record 48 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=khatanga
# Processing Record 49 | Victor Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=victor harbor
# Processing Record 50 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mount gambier
# Processing Record 51 | Woodward
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=woodward
# Processing Record 52 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mataura
# Processing Record 53 | The Pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=the pas
# Processing Record 54 | Ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ornskoldsvik
# Processing Record 55 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hithadhoo
# Processing Record 56 | Mikhaylovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mikhaylovka
# Processing Record 57 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hambantota
# Processing Record 58 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kruisfontein
# Processing Record 59 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bredasdorp
# Processing Record 60 | Altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=altay
# Processing Record 61 | Harer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=harer
# Processing Record 62 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mehamn
# Processing Record 63 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cape town
# Processing Record 64 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sitka
# City not found. Skipping...
# Processing Record 65 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=klaksvik
# Processing Record 66 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=belaya gora
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 67 | Jaszbereny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jaszbereny
# Processing Record 68 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint george
# Processing Record 69 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=laguna
# City not found. Skipping...
# Processing Record 70 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hirara
# Processing Record 71 | Coronon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=coronon
# Processing Record 72 | Shemonaikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=shemonaikha
# Processing Record 73 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mahebourg
# Processing Record 74 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tessalit
# Processing Record 75 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=severo-kurilsk
# Processing Record 76 | Changji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=changji
# Processing Record 77 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vaini
# Processing Record 78 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=provideniya
# Processing Record 79 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=chokurdakh
# Processing Record 80 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=longyearbyen
# Processing Record 81 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kununurra
# Processing Record 82 | Nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nacala
# Processing Record 83 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fortuna
# Processing Record 84 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ixtapa
# Processing Record 85 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saldanha
# Processing Record 86 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bathsheba
# Processing Record 87 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kavieng
# Processing Record 88 | Mufulira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mufulira
# Processing Record 89 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hasaki
# Processing Record 90 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bereda
# City not found. Skipping...
# Processing Record 91 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port macquarie
# Processing Record 92 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=byron bay
# Processing Record 93 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tiksi
# Processing Record 94 | Japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=japura
# Processing Record 95 | Houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=houma
# City not found. Skipping...
# Processing Record 96 | Piopio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=piopio
# Processing Record 97 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=aklavik
# Processing Record 98 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=san patricio
# Processing Record 99 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cidreira
# City not found. Skipping...
# Processing Record 100 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=rio gallegos
# Processing Record 101 | Cam Ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cam ranh
# Processing Record 102 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=chuy
# Processing Record 103 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pangnirtung
# Processing Record 104 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=carnarvon
# Processing Record 105 | Tsogni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tsogni
# Processing Record 106 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=east london
# Processing Record 107 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hilo
# Processing Record 108 | Coswig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=coswig
# Processing Record 109 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=clyde river
# Processing Record 110 | Lhokseumawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lhokseumawe
# Processing Record 111 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dikson
# Processing Record 112 | Tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tabas
# Processing Record 113 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=santa maria
# Processing Record 114 | Grafton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=grafton
# Processing Record 115 | Yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=yakeshi
# Processing Record 116 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=esperance
# Processing Record 117 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jalu
# Processing Record 118 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=qaanaaq
# Processing Record 119 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=samarai
# Processing Record 120 | Canby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=canby
# Processing Record 121 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cayenne
# Processing Record 122 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nantucket
# Processing Record 123 | Killybegs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=killybegs
# Processing Record 124 | Ishinomaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ishinomaki
# Processing Record 125 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lorengau
# Processing Record 126 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hermanus
# Processing Record 127 | Dalnerechensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dalnerechensk
# City not found. Skipping...
# Processing Record 128 | Tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tagusao
# Processing Record 129 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ostrovnoy
# Processing Record 130 | Lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lima
# Processing Record 131 | Crixas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=crixas
# Processing Record 132 | Lisala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lisala
# Processing Record 133 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dunedin
# Processing Record 134 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=upernavik
# Processing Record 135 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=yellowknife
# Processing Record 136 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=flinders
# Processing Record 137 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=grindavik
# Processing Record 138 | Fiche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fiche
# Processing Record 139 | Neyshabur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=neyshabur
# Processing Record 140 | Pangoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pangoa
# Processing Record 141 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port lincoln
# Processing Record 142 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mao
# Processing Record 143 | Washington DC.
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=washington
# Processing Record 144 | Tojsici
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tojsici
# City not found. Skipping...
# Processing Record 145 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vardo
# Processing Record 146 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=half moon bay
# Processing Record 147 | Ronne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ronne
# Processing Record 148 | Richha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=richha
# Processing Record 149 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=anadyr
# Processing Record 150 | Kolchugino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kolchugino
# Processing Record 151 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port hardy
# City not found. Skipping...
# Processing Record 152 | Vammala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vammala
# Processing Record 153 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=comodoro rivadavia
# Processing Record 154 | San Alberto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=san alberto
# Processing Record 155 | Haldibari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=haldibari
# Processing Record 156 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=guerrero negro
# City not found. Skipping...
# Processing Record 157 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=san cristobal
# Processing Record 158 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cabo san lucas
# Processing Record 159 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=atambua
# Processing Record 160 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nhulunbuy
# Processing Record 161 | Tevriz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tevriz
# Processing Record 162 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tucuman
# Processing Record 163 | Aloleng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=aloleng
# Processing Record 164 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint-philippe
# Processing Record 165 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nikolskoye
# City not found. Skipping...
# Processing Record 166 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tasiilaq
# Processing Record 167 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=katsuura
# Processing Record 168 | Willowmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=willowmore
# Processing Record 169 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=along
# Processing Record 170 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=beringovskiy
# Processing Record 171 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nizwa
# Processing Record 172 | Taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=taksimo
# Processing Record 173 | Diffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=diffa
# Processing Record 174 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lata
# Processing Record 175 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=alofi
# Processing Record 176 | Gram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=gram
# Processing Record 177 | Mont-Dore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mont-dore
# Processing Record 178 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bambous virieux
# Processing Record 179 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=salinas
# Processing Record 180 | Mundo Nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mundo nuevo
# Processing Record 181 | Kholodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kholodnyy
# Processing Record 182 | Srivardhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=srivardhan
# Processing Record 183 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=georgetown
# Processing Record 184 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=touros
# Processing Record 185 | Novyy Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=novyy urengoy
# Processing Record 186 | Canutama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=canutama
# Processing Record 187 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sao joao da barra
# Processing Record 188 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=richards bay
# Processing Record 189 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bethel
# Processing Record 190 | Urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=urucara
# Processing Record 191 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vila franca do campo
# Processing Record 192 | Pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pingliang
# Processing Record 193 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=coquimbo
# Processing Record 194 | Ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ola
# Processing Record 195 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=leningradskiy
# Processing Record 196 | Marghita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=marghita
# Processing Record 197 | Andreapol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=andreapol
# City not found. Skipping...
# Processing Record 198 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sao filipe
# Processing Record 199 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fairbanks
# Processing Record 200 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ponta do sol
# Processing Record 201 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mayo
# Processing Record 202 | Kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kichera
# Processing Record 203 | Hanstholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hanstholm
# Processing Record 204 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=aquiraz
# Processing Record 205 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 206 | Lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lokosovo
# Processing Record 207 | Zhoucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=zhoucheng
# Processing Record 208 | Palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=palana
# Processing Record 209 | Wuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=wuan
# Processing Record 210 | Kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kijang
# Processing Record 211 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saskylakh
# Processing Record 212 | Agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=agirish
# Processing Record 213 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nemuro
# Processing Record 214 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=arraial do cabo
# Processing Record 215 | Lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lufilufi
# City not found. Skipping...
# Processing Record 216 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port hedland
# Processing Record 217 | Vera Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vera cruz
# Processing Record 218 | Puli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=puli
# Processing Record 219 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kiunga
# Processing Record 220 | Scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=scottsbluff
# Processing Record 221 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=abu kamal
# Processing Record 222 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hofn
# Processing Record 223 | Viloco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=viloco
# City not found. Skipping...
# Processing Record 224 | Verkh-Usugli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=verkh-usugli
# Processing Record 225 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cherskiy
# City not found. Skipping...
# Processing Record 226 | Cairo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=cairo
# Processing Record 227 | Warmbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=warmbad
# Processing Record 228 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=turukhansk
# Processing Record 229 | Sarangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sarangani
# Processing Record 230 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=inhambane
# Processing Record 231 | Kadoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kadoma
# Processing Record 232 | Fomboni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fomboni
# Processing Record 233 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ahipara
# Processing Record 234 | Bodden Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bodden town
# Processing Record 235 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=khandyga
# Processing Record 236 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lompoc
# Processing Record 237 | Tabanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tabanan
# Processing Record 238 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=brae
# Processing Record 239 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fukue
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 240 | Ashitkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ashitkovo
# Processing Record 241 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pevek
# Processing Record 242 | Calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=calama
# Processing Record 243 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=rocha
# Processing Record 244 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=gat
# Processing Record 245 | Diu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=diu
# Processing Record 246 | Moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=moranbah
# Processing Record 247 | Vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vysokogornyy
# Processing Record 248 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kahului
# Processing Record 249 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=faanui
# Processing Record 250 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=gamba
# Processing Record 251 | Puerto Penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=puerto penasco
# Processing Record 252 | Scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=scarborough
# Processing Record 253 | Hurricane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hurricane
# Processing Record 254 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bubaque
# Processing Record 255 | Sovetskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sovetskoye
# Processing Record 256 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=abu dhabi
# Processing Record 257 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port-gentil
# Processing Record 258 | Lubyany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lubyany
# Processing Record 259 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=olinda
# Processing Record 260 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sinnamary
# Processing Record 261 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ribeira grande
# Processing Record 262 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=codrington
# City not found. Skipping...
# Processing Record 263 | Sokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sokolo
# City not found. Skipping...
# Processing Record 264 | Novyy Urgal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=novyy urgal
# Processing Record 265 | Jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jasper
# Processing Record 266 | Dedza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dedza
# Processing Record 267 | San Ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=san ramon
# Processing Record 268 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=auki
# Processing Record 269 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=port augusta
# Processing Record 270 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=yumen
# Processing Record 271 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=alice springs
# Processing Record 272 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=solnechnyy
# Processing Record 273 | Kolokani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kolokani
# Processing Record 274 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint-augustin
# Processing Record 275 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint anthony
# Processing Record 276 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nishihara
# Processing Record 277 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=airai
# Processing Record 278 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=halifax
# Processing Record 279 | Pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pandan
# Processing Record 280 | Nerchinskiy Zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nerchinskiy zavod
# Processing Record 281 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=banjar
# Processing Record 282 | Amarillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=amarillo
# City not found. Skipping...
# Processing Record 283 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=yerbogachen
# City not found. Skipping...
# Processing Record 284 | Zunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=zunyi
# Processing Record 285 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=berlevag
# Processing Record 286 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=hobyo
# Processing Record 287 | Pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=pringsewu
# Processing Record 288 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=yar-sale
# Processing Record 289 | Parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=parana
# Processing Record 290 | Alexandroupoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=alexandroupoli
# Processing Record 291 | San Lorenzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=san lorenzo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 292 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sungairaya
# Processing Record 293 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=namibe
# City not found. Skipping...
# Processing Record 294 | Las Vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=las vegas
# Processing Record 295 | Gedo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=gedo
# City not found. Skipping...
# Processing Record 296 | Traverse City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=traverse city
# Processing Record 297 | La Orilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=la orilla
# Processing Record 298 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=torbay
# Processing Record 299 | Masuda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=masuda
# Processing Record 300 | Tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tutoia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 301 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=te anau
# Processing Record 302 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=burnie
# Processing Record 303 | Vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vytegra
# Processing Record 304 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=haines junction
# Processing Record 305 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nome
# Processing Record 306 | Martil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=martil
# Processing Record 307 | Kuldur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kuldur
# Processing Record 308 | Fort Wellington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fort wellington
# Processing Record 309 | Groningen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=groningen
# City not found. Skipping...
# Processing Record 310 | Bo Rai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=bo rai
# Processing Record 311 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=petropavlovsk-kamchatskiy
# Processing Record 312 | Miles City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=miles city
# Processing Record 313 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kirakira
# Processing Record 314 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=acapulco
# Processing Record 315 | Dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dawlatabad
# Processing Record 316 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=salalah
# Processing Record 317 | Tyulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tyulgan
# Processing Record 318 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=daru
# Processing Record 319 | Moroni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=moroni
# Processing Record 320 | Tornio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tornio
# Processing Record 321 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=north bend
# Processing Record 322 | Anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=anloga
# Processing Record 323 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=whitehorse
# Processing Record 324 | Tahoua
# ...
# Processing Record 441 | Balaguer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=balaguer
# Processing Record 442 | Sao Raimundo das Mangabeiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sao raimundo das mangabeiras
# Processing Record 443 | Warwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=warwick
# Processing Record 444 | Sapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sapa
# City not found. Skipping...
# Processing Record 445 | Basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=basco
# Processing Record 446 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=zhigansk
# Processing Record 447 | Benito Juarez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=benito juarez
# Processing Record 448 | Farafenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=farafenni
# Processing Record 449 | Komatipoort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=komatipoort
# Processing Record 450 | Mbekenyera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mbekenyera
# Processing Record 451 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=labuan
# Processing Record 452 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=taltal
# Processing Record 453 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=walvis bay
# Processing Record 454 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=high level
# Processing Record 455 | Carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=carauari
# Processing Record 456 | Jieshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jieshi
# Processing Record 457 | Florenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=florenville
# Processing Record 458 | Alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=alekseyevsk
# Processing Record 459 | Barra da Estiva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=barra da estiva
# City not found. Skipping...
# Processing Record 460 | Goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=goundam
# Processing Record 461 | Carndonagh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=carndonagh
# Processing Record 462 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=atar
# Processing Record 463 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=labuhan
# City not found. Skipping...
# Processing Record 464 | Rutland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=rutland
# Processing Record 465 | Klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=klyuchi
# Processing Record 466 | Jiaohe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jiaohe
# City not found. Skipping...
# Processing Record 467 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lethem
# Processing Record 468 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=karratha
# Processing Record 469 | Malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=malanje
# Processing Record 470 | Houston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=houston
# Processing Record 471 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tautira
# Processing Record 472 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=vao
# Processing Record 473 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=christchurch
# Processing Record 474 | Selfoss
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=selfoss
# Processing Record 475 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=marzuq
# Processing Record 476 | Brunsbuttel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=brunsbuttel
# Processing Record 477 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=fort nelson
# Processing Record 478 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=maragogi
# Processing Record 479 | Lumberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lumberton
# Processing Record 480 | Corrente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=corrente
# City not found. Skipping...
# Processing Record 481 | Timmins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=timmins
# City not found. Skipping...
# Processing Record 482 | Saint-Denis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint-denis
# Processing Record 483 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=makakilo city
# Processing Record 484 | Kamenz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kamenz
# City not found. Skipping...
# Processing Record 485 | Atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=atherton
# Processing Record 486 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kieta
# Processing Record 487 | Churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=churapcha
# Processing Record 488 | Conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=conde
# Processing Record 489 | Lobito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lobito
# Processing Record 490 | Kaoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kaoma
# Processing Record 491 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=carutapera
# Processing Record 492 | Mukhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mukhen
# Processing Record 493 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=moose factory
# Processing Record 494 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=maniitsoq
# Processing Record 495 | Lahat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lahat
# Processing Record 496 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nanortalik
# Processing Record 497 | Mezhdurechensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mezhdurechensk
# Processing Record 498 | Dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dicabisagan
# Processing Record 499 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=benguela
# Processing Record 500 | Rafaela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=rafaela
# Processing Record 501 | Gold Coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=gold coast
# Processing Record 502 | Kang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kang
# Processing Record 503 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=egvekinot
# Processing Record 504 | Sao Felix do Xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sao felix do xingu
# Processing Record 505 | Watari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=watari
# Processing Record 506 | Shwebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=shwebo
# Processing Record 507 | Okahandja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=okahandja
# Processing Record 508 | Kabinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kabinda
# City not found. Skipping...
# Processing Record 509 | San Javier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=san javier
# Processing Record 510 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=padang
# Processing Record 511 | Dietzenbach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dietzenbach
# Processing Record 512 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tuatapere
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 513 | Saraland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saraland
# Processing Record 514 | Sohag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sohag
# Processing Record 515 | Zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=zhuhai
# Processing Record 516 | Lingao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=lingao
# City not found. Skipping...
# Processing Record 517 | Tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tupik
# Processing Record 518 | Plouzane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=plouzane
# Processing Record 519 | Taboga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=taboga
# Processing Record 520 | Dillon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=dillon
# Processing Record 521 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=saint-francois
# Processing Record 522 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=nuuk
# Processing Record 523 | Virginia Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=virginia beach
# Processing Record 524 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=homer
# Processing Record 525 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=trairi
# Processing Record 526 | Chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=chara
# City not found. Skipping...
# Processing Record 527 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=constitucion
# City not found. Skipping...
# Processing Record 528 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=maceio
# Processing Record 529 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=kavaratti
# Processing Record 530 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=marawi
# Processing Record 531 | Jagraon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=jagraon
# Processing Record 532 | Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=tecoanapa
# Processing Record 533 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=ossora
# Processing Record 534 | Sivas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sivas
# Processing Record 535 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=poum
# Processing Record 536 | Susanville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=susanville
# Processing Record 537 | Katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=katherine
# Processing Record 538 | Malangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=malangwa
# Processing Record 539 | Agboville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=agboville
# Processing Record 540 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=sept-iles
# Processing Record 541 | Irbeyskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=irbeyskoye
# Processing Record 542 | Concarneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=concarneau
# Processing Record 543 | The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=the valley
# Processing Record 544 | Oriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=oriximina
# Processing Record 545 | Huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=huilong
# Processing Record 546 | Iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=iquique
# Processing Record 547 | Mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=65d8f4f8dee7e491ee80385d694f48f3&q=mehran

# %%
city_name
# Out:
# ['Albany',
#  'Monywa',
#  'Maningrida',
#  'Kodiak',
#  'Mar del Plata',
#  'Kapaa',
#  'Ushuaia',
#  'Quatre Cocos',
#  'Souillac',
#  'Saint-Pierre',
#  'Barrow',
#  'Areia Branca',
#  'Port Elizabeth',
#  'Luderitz',
#  'Mangan',
#  'Puerto Ayora',
#  'Victoria',
#  'Gunnedah',
#  'Ridgecrest',
#  'Ishigaki',
#  'Dalvik',
#  'Cabedelo',
#  'Butaritari',
#  'Castro',
#  'Olden',
#  'New Norfolk',
#  'Talnakh',
#  'Lebu',
#  'Vila Velha',
#  'Thompson',
#  'Zheleznogorsk',
#  'Hobart',
#  'Rikitea',
#  'Busselton',
#  'Geraldton',
#  'Ancud',
#  'Port Alfred',
#  'Pisco',
#  'Punta Arenas',
#  'Cairns',
#  'Atuona',
#  'Jamestown',
#  'Iqaluit',
#  'Bluff',
#  'Avarua',
#  'Kaitangata',
#  'Khuzdar',
#  'Khatanga',
#  'Victor Harbor',
#  'Mount Gambier',
#  'Woodward',
#  'Mataura',
#  'The Pas',
#  'Ornskoldsvik',
#  'Hithadhoo',
#  'Mikhaylovka',
#  'Hambantota',
#  'Kruisfontein',
#  'Bredasdorp',
#  'Altay',
#  'Harer',
#  'Mehamn',
#  'Cape Town',
#  'Sitka',
#  'Klaksvik',
#  'Belaya Gora',
#  'Jaszbereny',
#  'Saint George',
#  'Laguna',
#  'Hirara',
#  'Coronon',
#  'Shemonaikha',
#  'Mahebourg',
#  'Tessalit',
#  'Severo-Kurilsk',
#  'Changji',
#  'Vaini',
#  'Provideniya',
#  'Chokurdakh',
#  'Longyearbyen',
#  'Kununurra',
#  'Nacala',
#  'Fortuna',
#  'Ixtapa',
#  'Saldanha',
#  'Bathsheba',
#  'Kavieng',
#  'Mufulira',
#  'Hasaki',
#  'Bereda',
#  'Port Macquarie',
#  'Byron Bay',
#  'Tiksi',
#  'Japura',
#  'Houma',
#  'Piopio',
#  'Aklavik',
#  'San Patricio',
#  'Cidreira',
#  'Rio Gallegos',
#  'Cam Ranh',
#  'Chuy',
#  'Pangnirtung',
#  'Carnarvon',
#  'Tsogni',
#  'East London',
#  'Hilo',
#  'Coswig',
#  'Clyde River',
#  'Lhokseumawe',
#  'Dikson',
#  'Tabas',
#  'Santa Maria',
#  'Grafton',
#  'Yakeshi',
#  'Esperance',
#  'Jalu',
#  'Qaanaaq',
#  'Samarai',
#  'Canby',
#  'Cayenne',
#  'Nantucket',
#  'Killybegs',
#  'Ishinomaki',
#  'Lorengau',
#  'Hermanus',
#  'Dalnerechensk',
#  'Tagusao',
#  'Ostrovnoy',
#  'Lima',
#  'Crixas',
#  'Lisala',
#  'Dunedin',
#  'Upernavik',
#  'Yellowknife',
#  'Flinders',
#  'Grindavik',
#  'Fiche',
#  'Neyshabur',
#  'Pangoa',
#  'Port Lincoln',
#  'Mao',
#  'Washington DC.',
#  'Tojsici',
#  'Vardo',
#  'Half Moon Bay',
#  'Ronne',
#  'Richha',
#  'Anadyr',
#  'Kolchugino',
#  'Port Hardy',
#  'Vammala',
#  'Comodoro Rivadavia',
#  'San Alberto',
#  'Haldibari',
#  'Guerrero Negro',
#  'San Cristobal',
#  'Cabo San Lucas',
#  'Atambua',
#  'Nhulunbuy',
#  'Tevriz',
#  'Tucuman',
#  'Aloleng',
#  'Saint-Philippe',
#  'Nikolskoye',
#  'Tasiilaq',
#  'Katsuura',
#  'Willowmore',
#  'Along',
#  'Beringovskiy',
#  'Nizwa',
#  'Taksimo',
#  'Diffa',
#  'Lata',
#  'Alofi',
#  'Gram',
#  'Mont-Dore',
#  'Bambous Virieux',
#  'Salinas',
#  'Mundo Nuevo',
#  'Kholodnyy',
#  'Srivardhan',
#  'Georgetown',
#  'Touros',
#  'Novyy Urengoy',
#  'Canutama',
#  'Sao Joao da Barra',
#  'Richards Bay',
#  'Bethel',
#  'Urucara',
#  'Vila Franca do Campo',
#  'Pingliang',
#  'Coquimbo',
#  'Ola',
#  'Leningradskiy',
#  'Marghita',
#  'Andreapol',
#  'Sao Filipe',
#  'Fairbanks',
#  'Ponta do Sol',
#  'Mayo',
#  'Kichera',
#  'Hanstholm',
#  'Aquiraz',
#  'Tuktoyaktuk',
#  'Lokosovo',
#  'Zhoucheng',
#  'Palana',
#  'Wuan',
#  'Kijang',
#  'Saskylakh',
#  'Agirish',
#  'Nemuro',
#  'Arraial do Cabo',
#  'Lufilufi',
#  'Port Hedland',
#  'Vera Cruz',
#  'Puli',
#  'Kiunga',
#  'Scottsbluff',
#  'Abu Kamal',
#  'Hofn',
#  'Viloco',
#  'Verkh-Usugli',
#  'Cherskiy',
#  'Cairo',
#  'Warmbad',
#  'Turukhansk',
#  'Sarangani',
#  'Inhambane',
#  'Kadoma',
#  'Fomboni',
#  'Ahipara',
#  'Bodden Town',
#  'Khandyga',
#  'Lompoc',
#  'Tabanan',
#  'Brae',
#  'Fukue',
#  'Ashitkovo',
#  'Pevek',
#  'Calama',
#  'Rocha',
#  'Gat',
#  'Diu',
#  'Moranbah',
#  'Vysokogornyy',
#  'Kahului',
#  'Faanui',
#  'Gamba',
#  'Puerto Penasco',
#  'Scarborough',
#  'Hurricane',
#  'Bubaque',
#  'Sovetskoye',
#  'Abu Dhabi',
#  'Port-Gentil',
#  'Lubyany',
#  'Olinda',
#  'Sinnamary',
#  'Ribeira Grande',
#  'Codrington',
#  'Sokolo',
#  'Novyy Urgal',
#  'Jasper',
#  'Dedza',
#  'San Ramon',
#  'Auki',
#  'Port Augusta',
#  'Yumen',
#  'Alice Springs',
#  'Solnechnyy',
#  'Kolokani',
#  'Saint-Augustin',
#  'Saint Anthony',
#  'Nishihara',
#  'Airai',
#  'Halifax',
#  'Pandan',
#  'Nerchinskiy Zavod',
#  'Banjar',
#  'Amarillo',
#  'Yerbogachen',
#  'Zunyi',
#  'Berlevag',
#  'Hobyo',
#  'Pringsewu',
#  'Yar-Sale',
#  'Parana',
#  'Alexandroupoli',
#  'San Lorenzo',
#  'Sungairaya',
#  'Namibe',
#  'Las Vegas',
#  'Gedo',
#  'Traverse City',
#  'La Orilla',
#  'Torbay',
#  'Masuda',
#  'Tutoia',
#  'Te Anau',
#  'Burnie',
#  'Vytegra',
#  'Haines Junction',
#  'Nome',
#  'Martil',
#  'Kuldur',
#  'Fort Wellington',
#  'Groningen',
#  'Bo Rai',
#  'Petropavlovsk-Kamchatskiy',
#  'Miles City',
#  'Kirakira',
#  'Acapulco',
#  'Dawlatabad',
#  'Salalah',
#  'Tyulgan',
#  'Daru',
#  'Moroni',
#  'Tornio',
#  'North Bend',
#  'Anloga',
#  'Whitehorse',
#  'Tahoua',
#  'Camacha',
#  'Bafra',
#  'Papetoai',
#  'Komsomolskiy',
#  'College',
#  'Hammerfest',
#  'Cassilandia',
#  'Dawson Creek',
#  'Saint-Joseph',
#  'Narsaq',
#  'Belmonte',
#  'Guatire',
#  'Udachnyy',
#  'Dinguiraye',
#  'Kamenka',
#  'Yangmei',
#  'Raymond',
#  'Leeton',
#  'Karla',
#  'Vostok',
#  'Hanzhong',
#  'Lewistown',
#  'Terney',
#  'Yatou',
#  'Rawson',
#  'Devgarh',
#  'Cuiluan',
#  'Minsk',
#  'Prince Rupert',
#  'Ilulissat',
#  'Gambela',
#  'Sabang',
#  'Noshiro',
#  'Roncesvalles',
#  'Xinzhou',
#  'Veinticinco de Mayo',
#  'Paita',
#  'Harper',
#  'Corrales',
#  'Itarema',
#  'Hamilton',
#  'Kulhudhuffushi',
#  'Qaqortoq',
#  'Severo-Yeniseyskiy',
#  'Puntarenas',
#  'Tilichiki',
#  'Lipin Bor',
#  'Santa Cruz',
#  'Vilhena',
#  'Kon Tum',
#  'Anahuac',
#  'Panama City',
#  'Okhotsk',
#  'Siva',
#  'Bara',
#  'Orocue',
#  'Sabha',
#  'Mount Isa',
#  'Skibbereen',
#  'Makaha',
#  'Tonantins',
#  'Husavik',
#  'Road Town',
#  'Awjilah',
#  'Dauphin',
#  'Mago',
#  'Astara',
#  'Abancay',
#  'Dwarka',
#  'Kaman',
#  'Caravelas',
#  'Vanavara',
#  'Aswan',
#  'Bourail',
#  'Seymchan',
#  'Ararangua',
#  'Black River',
#  'Garowe',
#  'Almaguer',
#  'Yinchuan',
#  'Marrakesh',
#  'Yulara',
#  'Boende',
#  'Pacific Grove',
#  'Lagoa',
#  'Honiara',
#  'Atbasar',
#  'Luanda',
#  'Roald',
#  'Madang',
#  'Gawler',
#  'Teyateyaneng',
#  'Calamar',
#  'Manokwari',
#  'Terenos',
#  'Honningsvag',
#  'Los Llanos de Aridane',
#  'Kimbe',
#  'Palmer',
#  'Manolas',
#  'Ormara',
#  'Sangmelima',
#  'Norsup',
#  'Barkly West',
#  'Rome',
#  'Morehead',
#  'Huarmey',
#  'Bonfim',
#  'Cervo',
#  'Hegang',
#  'Poronaysk',
#  'Erenhot',
#  'Norman Wells',
#  'Astana',
#  'Adrar',
#  'Beyneu',
#  'Balaguer',
#  'Sao Raimundo das Mangabeiras',
#  'Warwick',
#  'Sapa',
#  'Basco',
#  'Zhigansk',
#  'Benito Juarez',
#  'Farafenni',
#  'Komatipoort',
#  'Mbekenyera',
#  'Victoria',
#  'Taltal',
#  'Walvis Bay',
#  'High Level',
#  'Carauari',
#  'Jieshi',
#  'Florenville',
#  'Alekseyevsk',
#  'Barra da Estiva',
#  'Goundam',
#  'Carndonagh',
#  'Atar',
#  'Labuhan',
#  'Rutland',
#  'Klyuchi',
#  'Jiaohe',
#  'Lethem',
#  'Karratha',
#  'Malanje',
#  'Houston',
#  'Tautira',
#  'Vao',
#  'Christchurch',
#  'Selfoss',
#  'Marzuq',
#  'Brunsbuttel',
#  'Fort Nelson',
#  'Maragogi',
#  'Lumberton',
#  'Corrente',
#  'Timmins',
#  'Saint-Denis',
#  'Makakilo City',
#  'Kamenz',
#  'Atherton',
#  'Kieta',
#  'Churapcha',
#  'Conde',
#  'Lobito',
#  'Kaoma',
#  'Carutapera',
#  'Mukhen',
#  'Moose Factory',
#  'Maniitsoq',
#  'Lahat',
#  'Nanortalik',
#  'Mezhdurechensk',
#  'Dicabisagan',
#  'Benguela',
#  'Rafaela',
#  'Gold Coast',
#  'Kang',
#  'Egvekinot',
#  'Sao Felix do Xingu',
#  'Watari',
#  'Shwebo',
#  'Okahandja',
#  'Kabinda',
#  'San Javier',
#  'Padang',
#  'Dietzenbach',
#  'Tuatapere',
#  'Saraland',
#  'Sohag',
#  'Zhuhai',
#  'Lingao',
#  'Tupik',
#  'Plouzane',
#  'Taboga',
#  'Dillon',
#  'Saint-Francois',
#  'Nuuk',
#  'Virginia Beach',
#  'Homer',
#  'Trairi',
#  'Chara',
#  'Constitucion',
#  'Maceio',
#  'Kavaratti',
#  'Marawi',
#  'Jagraon',
#  'Tecoanapa',
#  'Ossora',
#  'Sivas',
#  'Poum',
#  'Susanville',
#  'Katherine',
#  'Malangwa',
#  'Agboville',
#  'Sept-Iles',
#  'Irbeyskoye',
#  'Concarneau',
#  'The Valley',
#  'Oriximina',
#  'Huilong',
#  'Iquique',
#  'Mehran']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# make dictionary for pandas to read
city_data = {
    'name': city_name,
    'cloudiness': cloudiness,
    'country': country,
    'date': date,
    'humdity': humidity,
    'lat': lat,
    'lng': lng,
    'max temp': max_temp,
    'wind speed': wind_speed,
}

# %%
city_df = pd.DataFrame(city_data)
city_df
# Out:
#                name  cloudiness country        date  humdity    lat     lng  \
# 0            Albany          40      US  1563998428       44  42.65  -73.75
# 1            Monywa         100      MM  1563998429       80  22.12   95.13
# 2        Maningrida          50      AU  1563998429       90 -12.05  134.23
# 3            Kodiak          20      US  1563998429       42  39.95  -94.76
# 4     Mar del Plata           0      AR  1563998328       61 -46.43  -67.52
# 5             Kapaa          40      US  1563998430       70  22.08 -159.32
# 6           Ushuaia           0      AR  1563998340       69 -54.81  -68.31
# 7      Quatre Cocos          75      MU  1563998430       88 -20.21   57.76
# 8          Souillac           0      FR  1563998430       38  45.60   -0.60
# 9      Saint-Pierre           0      FR  1563998430       33  48.95    4.24
# 10           Barrow           0      AR  1563998431       42 -38.31  -60.23
# 11     Areia Branca          20      BR  1563998431       61 -10.76  -37.31
# 12   Port Elizabeth           1      US  1563998431       51  39.31  -74.98
# 13         Luderitz           0      NA  1563998189       71 -26.65   15.16
# 14           Mangan         100      IN  1563998431       92  27.50   88.54
# 15     Puerto Ayora          75      EC  1563998432       61  -0.74  -90.35
# 16         Victoria          75      BN  1563998432       94   5.28  115.24
# 17         Gunnedah           0      AU  1563998432       89 -30.98  150.25
# 18       Ridgecrest          20      US  1563998432       15  35.62 -117.67
# 19         Ishigaki          85      JP  1563998433       79  24.34  124.16
# 20           Dalvik           0      SE  1563998433       68  57.79   14.13
# 21         Cabedelo          90      BR  1563998433      100  -6.97  -34.84
# 22       Butaritari          33      KI  1563998433       71   3.07  172.79
# 23           Castro           0      CL  1563998434       71 -42.48  -73.76
# 24            Olden          40      NO  1563998434       60  61.84    6.81
# 25      New Norfolk          75      AU  1563998434       62 -42.78  147.06
# 26          Talnakh          75      RU  1563998434       58  69.49   88.39
# 27             Lebu          75      ET  1563998434       87   8.96   38.73
# 28       Vila Velha           0      BR  1563998435       61  -3.71  -38.60
# 29         Thompson          40      CA  1563998435       33  55.74  -97.86
# ..              ...         ...     ...         ...      ...    ...     ...
# 517        Plouzane           0      FR  1563998551       64  48.38   -4.62
# 518          Taboga           0      IT  1563998552       69  46.27   13.11
# 519          Dillon          20      US  1563998552       39  45.22 -112.64
# 520  Saint-Francois           0      FR  1563998552       38  46.42    3.91
# 521            Nuuk          75      GL  1563998552       81  64.17  -51.74
# 522  Virginia Beach          90      US  1563998539       69  36.85  -75.98
# 523           Homer          90      US  1563998552       72  59.64 -151.54
# 524          Trairi          95      BR  1563998408       69  -3.28  -39.27
# 525           Chara          20      GR  1563998553       73  39.42   22.43
# 526    Constitucion          75      MX  1563998553       49  23.99 -104.67
# 527          Maceio          90      BR  1563998553       83  -9.67  -35.74
# 528       Kavaratti         100      IN  1563998554       80  10.57   72.64
# 529          Marawi          83      PH  1563998554       95   8.00  124.29
# 530         Jagraon           9      IN  1563998554       51  30.80   75.48
# 531       Tecoanapa          75      MX  1563998554       66  16.99  -99.26
# 532          Ossora         100      RU  1563998555       54  59.24  163.07
# 533           Sivas           0      TR  1563998555       82  39.75   37.01
# 534            Poum          20      MK  1563998555       52  41.28   20.71
# 535      Susanville           1      US  1563998555       19  40.42 -120.65
# 536       Katherine          42      AU  1563998556       62 -14.47  132.26
# 537        Malangwa           6      CD  1563998556       40  -2.84   17.57
# 538       Agboville           4      CI  1563998556       91   5.93   -4.21
# 539       Sept-Iles          40      CA  1563998480       52  50.20  -66.38
# 540      Irbeyskoye         100      RU  1563998556       92  55.64   95.45
# 541      Concarneau           0      FR  1563998557       68  47.88   -3.92
# 542      The Valley          20      AI  1563998560       58  18.22  -63.06
# 543       Oriximina           0      BR  1563998560       49  -1.77  -55.87
# 544         Huilong         100      CN  1563998560       89  31.15  106.50
# 545         Iquique          75      CL  1563998560       63 -20.22  -70.14
# 546          Mehran           0      IR  1563998561       12  33.12   46.17
#
#      max temp  wind speed
# 0       81.00        5.82
# 1       77.92       10.58
# 2       68.29       10.07
# 3       82.00        4.70
# 4       44.96       11.74
# 5       84.20       13.87
# 6       39.20        6.96
# 7       69.80       17.22
# 8       93.20        3.36
# 9       89.60        4.70
# 10      46.71        4.21
# 11      80.60       12.75
# 12      87.01       11.41
# 13      55.40       12.75
# 14      59.02        0.09
# 15      78.80       23.04
# 16      77.00       10.33
# 17      33.80        3.36
# 18     105.01       11.41
# 19      83.25       11.48
# 20      72.00        3.36
# 21      71.60       11.41
# 22      83.95        4.81
# 23      50.00        4.70
# 24      75.20        4.70
# 25      54.00       11.41
# 26      57.20       35.79
# 27      59.00        0.87
# 28      86.00       11.41
# 29      86.00        6.93
# ..        ...         ...
# 517     71.60        5.82
# 518     84.20        4.70
# 519     87.01       14.99
# 520     87.80        4.16
# 521     48.20       12.75
# 522     82.40        9.17
# 523     60.80        3.36
# 524     78.77        3.94
# 525     79.00       13.87
# 526     72.00        3.36
# 527     75.20        6.93
# 528     81.49       17.11
# 529     73.00        5.99
# 530     90.54        7.00
# 531     87.80        4.70
# 532     53.86        4.79
# 533     59.00       10.29
# 534     69.80        5.82
# 535     88.00        5.82
# 536     57.20        4.70
# 537     83.05        1.36
# 538     71.50        3.49
# 539     66.99       17.22
# 540     55.08        5.66
# 541     72.00        4.70
# 542     87.80       17.22
# 543     88.74        6.24
# 544     74.68        1.59
# 545     60.80       18.34
# 546     78.80        6.93
#
# [547 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-10b0080549ae> in <module>
#       1 # Build a scatter plot for each data type
# ----> 2 plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("City Latitude vs. Max Temperature")
#
# NameError: name 'weather_data' is not defined

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
